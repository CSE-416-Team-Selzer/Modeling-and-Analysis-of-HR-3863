# %%
import geopandas

# %%
us = geopandas.read_file('data/US/us-states.json')
display(us.plot())
# Out:
# <AxesSubplot: >

# %%
us = us[(us['id'] == '04') | (us['id'] == '48') | (us['id'] == '49')]

# %%
display(us)
display(us.plot())
# Out:
#     id     name  density                                           geometry
# 2   04  Arizona    57.05  POLYGON ((-109.04250 37.00026, -109.04798 31.3...
# 43  48    Texas    98.07  POLYGON ((-101.81294 36.50186, -100.00007 36.5...
# 44  49     Utah    34.30  POLYGON ((-112.16436 41.99523, -111.04706 42.0...
# <AxesSubplot: >

# %%
us.to_file('data/US/us-states-pruned.json', driver='GeoJSON', index = True)
