# %%
import geopandas
import math

# %%
az = geopandas.read_file('raw_data/Arizona/cb_2020_04_tract_500k.shp')
tx = geopandas.read_file('raw_data/Texas/cb_2020_48_tract_500k.shp')
ut = geopandas.read_file('raw_data/Utah/cb_2020_49_tract_500k.shp')
tx2 = geopandas.read_file('raw_data/Not_Texas/cb_2020_48_sldu_500k.shp')

# %%
##az.plot()
##tx.plot()
##ut.plot()

# %%
display(tx2)
# Out:
#    STATEFP SLDUST        AFFGEOID  GEOID NAME                  NAMELSAD  \
# 0       48    007  610U600US48007  48007    7   State Senate District 7
# 1       48    016  610U600US48016  48016   16  State Senate District 16
# 2       48    013  610U600US48013  48013   13  State Senate District 13
# 3       48    011  610U600US48011  48011   11  State Senate District 11
# 4       48    028  610U600US48028  48028   28  State Senate District 28
# 5       48    006  610U600US48006  48006    6   State Senate District 6
# 6       48    026  610U600US48026  48026   26  State Senate District 26
# 7       48    014  610U600US48014  48014   14  State Senate District 14
# 8       48    027  610U600US48027  48027   27  State Senate District 27
# 9       48    017  610U600US48017  48017   17  State Senate District 17
# 10      48    031  610U600US48031  48031   31  State Senate District 31
# 11      48    021  610U600US48021  48021   21  State Senate District 21
# 12      48    009  610U600US48009  48009    9   State Senate District 9
# 13      48    023  610U600US48023  48023   23  State Senate District 23
# 14      48    002  610U600US48002  48002    2   State Senate District 2
# 15      48    003  610U600US48003  48003    3   State Senate District 3
# 16      48    008  610U600US48008  48008    8   State Senate District 8
# 17      48    030  610U600US48030  48030   30  State Senate District 30
# 18      48    029  610U600US48029  48029   29  State Senate District 29
# 19      48    005  610U600US48005  48005    5   State Senate District 5
# 20      48    024  610U600US48024  48024   24  State Senate District 24
# 21      48    020  610U600US48020  48020   20  State Senate District 20
# 22      48    012  610U600US48012  48012   12  State Senate District 12
# 23      48    022  610U600US48022  48022   22  State Senate District 22
# 24      48    010  610U600US48010  48010   10  State Senate District 10
# 25      48    025  610U600US48025  48025   25  State Senate District 25
# 26      48    019  610U600US48019  48019   19  State Senate District 19
# 27      48    018  610U600US48018  48018   18  State Senate District 18
# 28      48    004  610U600US48004  48004    4   State Senate District 4
# 29      48    015  610U600US48015  48015   15  State Senate District 15
# 30      48    001  610U600US48001  48001    1   State Senate District 1
#
#    STUSPS STATE_NAME LSAD   LSY         ALAND      AWATER  \
# 0      TX      Texas   LU  2018     924461058     7441750
# 1      TX      Texas   LU  2018     625296466    18563840
# 2      TX      Texas   LU  2018     543608220     4554332
# 3      TX      Texas   LU  2018    2983983804  1055090498
# 4      TX      Texas   LU  2018  125489990335   649029316
# 5      TX      Texas   LU  2018     682364150    58190489
# 6      TX      Texas   LU  2018     477405321     2048799
# 7      TX      Texas   LU  2018    3957667402    69559237
# 8      TX      Texas   LU  2018   11024240313  3322819117
# 9      TX      Texas   LU  2018    2903514390   326680982
# 10     TX      Texas   LU  2018   94500394086   351189653
# 11     TX      Texas   LU  2018   44359555244   460377725
# 12     TX      Texas   LU  2018     697585191     5551120
# 13     TX      Texas   LU  2018     944902931    37556466
# 14     TX      Texas   LU  2018   12712693069   528819603
# 15     TX      Texas   LU  2018   40389916437  1736872249
# 16     TX      Texas   LU  2018     797609506    14857044
# 17     TX      Texas   LU  2018   31078332351   749658335
# 18     TX      Texas   LU  2018   40185539048    10047614
# 19     TX      Texas   LU  2018   21930859345   319890242
# 20     TX      Texas   LU  2018   38341069610   422166452
# 21     TX      Texas   LU  2018    9722374092   180482909
# 22     TX      Texas   LU  2018    1810070159   178336879
# 23     TX      Texas   LU  2018   18263462066   529559734
# 24     TX      Texas   LU  2018    1037637164    28052332
# 25     TX      Texas   LU  2018    6200173074    49617164
# 26     TX      Texas   LU  2018   91647500013   427686234
# 27     TX      Texas   LU  2018   38496813537  4610705689
# 28     TX      Texas   LU  2018    6313893057  1972792427
# 29     TX      Texas   LU  2018     828734514    37403360
# 30     TX      Texas   LU  2018   26808942961   813750639
#
#                                              geometry
# 0   POLYGON ((-95.78235 30.02745, -95.78158 30.027...
# 1   POLYGON ((-97.03384 32.83853, -97.03358 32.852...
# 2   POLYGON ((-95.61470 29.71341, -95.60467 29.714...
# 3   MULTIPOLYGON (((-94.82326 29.32392, -94.82279 ...
# 4   POLYGON ((-103.61089 31.65180, -103.37029 31.6...
# 5   MULTIPOLYGON (((-94.97839 29.68365, -94.97743 ...
# 6   POLYGON ((-98.71066 29.48182, -98.70984 29.483...
# 7   POLYGON ((-98.12313 30.48704, -98.11687 30.498...
# 8   MULTIPOLYGON (((-97.25287 26.37530, -97.25050 ...
# 9   POLYGON ((-95.87249 29.50659, -95.87030 29.508...
# 10  POLYGON ((-103.98394 31.99411, -103.98175 31.9...
# 11  MULTIPOLYGON (((-97.23878 27.83565, -97.23856 ...
# 12  POLYGON ((-97.34885 32.90978, -97.34873 32.915...
# 13  POLYGON ((-97.03852 32.56000, -97.03840 32.566...
# 14  POLYGON ((-96.76450 32.80823, -96.76114 32.811...
# 15  POLYGON ((-96.45455 32.35232, -96.45308 32.352...
# 16  POLYGON ((-96.84410 32.98891, -96.84403 32.992...
# 17  POLYGON ((-98.95394 33.39753, -98.95383 33.489...
# 18  POLYGON ((-106.64548 31.89867, -106.64084 31.9...
# 19  POLYGON ((-98.04989 30.62415, -98.03034 30.660...
# 20  POLYGON ((-100.15184 32.09064, -100.15170 32.1...
# 21  MULTIPOLYGON (((-97.24647 27.68248, -97.23737 ...
# 22  POLYGON ((-97.54798 32.79840, -97.54770 32.821...
# 23  POLYGON ((-98.06808 32.52341, -98.06684 32.558...
# 24  POLYGON ((-97.55053 32.56258, -97.55053 32.562...
# 25  POLYGON ((-98.92061 29.98912, -98.92049 30.084...
# 26  POLYGON ((-104.10103 31.12474, -104.10033 31.1...
# 27  MULTIPOLYGON (((-97.12705 27.84106, -97.12289 ...
# 28  MULTIPOLYGON (((-94.71830 29.72885, -94.71721 ...
# 29  POLYGON ((-95.57473 29.86719, -95.56919 29.867...
# 30  POLYGON ((-95.85772 33.46272, -95.85712 33.495...

# %%
tx2.plot()
# Out:
# <AxesSubplot: >

# %%
az['countyNum'] = az['COUNTYFP']
tx['countyNum'] = tx['COUNTYFP']
ut['countyNum'] = ut['COUNTYFP']

az = az.dissolve(by = 'COUNTYFP')
tx = tx.dissolve(by = 'COUNTYFP')
ut = ut.dissolve(by = 'COUNTYFP')
##display(az)

# %%
azSMD = az.copy()
txSMD = tx2.copy()
utSMD = ut.copy()

azMMD = az.copy()
txMMD = tx2.copy()
utMMD = ut.copy()
display(tx2)
# Out:
#    STATEFP SLDUST        AFFGEOID  GEOID NAME                  NAMELSAD  \
# 0       48    007  610U600US48007  48007    7   State Senate District 7
# 1       48    016  610U600US48016  48016   16  State Senate District 16
# 2       48    013  610U600US48013  48013   13  State Senate District 13
# 3       48    011  610U600US48011  48011   11  State Senate District 11
# 4       48    028  610U600US48028  48028   28  State Senate District 28
# 5       48    006  610U600US48006  48006    6   State Senate District 6
# 6       48    026  610U600US48026  48026   26  State Senate District 26
# 7       48    014  610U600US48014  48014   14  State Senate District 14
# 8       48    027  610U600US48027  48027   27  State Senate District 27
# 9       48    017  610U600US48017  48017   17  State Senate District 17
# 10      48    031  610U600US48031  48031   31  State Senate District 31
# 11      48    021  610U600US48021  48021   21  State Senate District 21
# 12      48    009  610U600US48009  48009    9   State Senate District 9
# 13      48    023  610U600US48023  48023   23  State Senate District 23
# 14      48    002  610U600US48002  48002    2   State Senate District 2
# 15      48    003  610U600US48003  48003    3   State Senate District 3
# 16      48    008  610U600US48008  48008    8   State Senate District 8
# 17      48    030  610U600US48030  48030   30  State Senate District 30
# 18      48    029  610U600US48029  48029   29  State Senate District 29
# 19      48    005  610U600US48005  48005    5   State Senate District 5
# 20      48    024  610U600US48024  48024   24  State Senate District 24
# 21      48    020  610U600US48020  48020   20  State Senate District 20
# 22      48    012  610U600US48012  48012   12  State Senate District 12
# 23      48    022  610U600US48022  48022   22  State Senate District 22
# 24      48    010  610U600US48010  48010   10  State Senate District 10
# 25      48    025  610U600US48025  48025   25  State Senate District 25
# 26      48    019  610U600US48019  48019   19  State Senate District 19
# 27      48    018  610U600US48018  48018   18  State Senate District 18
# 28      48    004  610U600US48004  48004    4   State Senate District 4
# 29      48    015  610U600US48015  48015   15  State Senate District 15
# 30      48    001  610U600US48001  48001    1   State Senate District 1
#
#    STUSPS STATE_NAME LSAD   LSY         ALAND      AWATER  \
# 0      TX      Texas   LU  2018     924461058     7441750
# 1      TX      Texas   LU  2018     625296466    18563840
# 2      TX      Texas   LU  2018     543608220     4554332
# 3      TX      Texas   LU  2018    2983983804  1055090498
# 4      TX      Texas   LU  2018  125489990335   649029316
# 5      TX      Texas   LU  2018     682364150    58190489
# 6      TX      Texas   LU  2018     477405321     2048799
# 7      TX      Texas   LU  2018    3957667402    69559237
# 8      TX      Texas   LU  2018   11024240313  3322819117
# 9      TX      Texas   LU  2018    2903514390   326680982
# 10     TX      Texas   LU  2018   94500394086   351189653
# 11     TX      Texas   LU  2018   44359555244   460377725
# 12     TX      Texas   LU  2018     697585191     5551120
# 13     TX      Texas   LU  2018     944902931    37556466
# 14     TX      Texas   LU  2018   12712693069   528819603
# 15     TX      Texas   LU  2018   40389916437  1736872249
# 16     TX      Texas   LU  2018     797609506    14857044
# 17     TX      Texas   LU  2018   31078332351   749658335
# 18     TX      Texas   LU  2018   40185539048    10047614
# 19     TX      Texas   LU  2018   21930859345   319890242
# 20     TX      Texas   LU  2018   38341069610   422166452
# 21     TX      Texas   LU  2018    9722374092   180482909
# 22     TX      Texas   LU  2018    1810070159   178336879
# 23     TX      Texas   LU  2018   18263462066   529559734
# 24     TX      Texas   LU  2018    1037637164    28052332
# 25     TX      Texas   LU  2018    6200173074    49617164
# 26     TX      Texas   LU  2018   91647500013   427686234
# 27     TX      Texas   LU  2018   38496813537  4610705689
# 28     TX      Texas   LU  2018    6313893057  1972792427
# 29     TX      Texas   LU  2018     828734514    37403360
# 30     TX      Texas   LU  2018   26808942961   813750639
#
#                                              geometry
# 0   POLYGON ((-95.78235 30.02745, -95.78158 30.027...
# 1   POLYGON ((-97.03384 32.83853, -97.03358 32.852...
# 2   POLYGON ((-95.61470 29.71341, -95.60467 29.714...
# 3   MULTIPOLYGON (((-94.82326 29.32392, -94.82279 ...
# 4   POLYGON ((-103.61089 31.65180, -103.37029 31.6...
# 5   MULTIPOLYGON (((-94.97839 29.68365, -94.97743 ...
# 6   POLYGON ((-98.71066 29.48182, -98.70984 29.483...
# 7   POLYGON ((-98.12313 30.48704, -98.11687 30.498...
# 8   MULTIPOLYGON (((-97.25287 26.37530, -97.25050 ...
# 9   POLYGON ((-95.87249 29.50659, -95.87030 29.508...
# 10  POLYGON ((-103.98394 31.99411, -103.98175 31.9...
# 11  MULTIPOLYGON (((-97.23878 27.83565, -97.23856 ...
# 12  POLYGON ((-97.34885 32.90978, -97.34873 32.915...
# 13  POLYGON ((-97.03852 32.56000, -97.03840 32.566...
# 14  POLYGON ((-96.76450 32.80823, -96.76114 32.811...
# 15  POLYGON ((-96.45455 32.35232, -96.45308 32.352...
# 16  POLYGON ((-96.84410 32.98891, -96.84403 32.992...
# 17  POLYGON ((-98.95394 33.39753, -98.95383 33.489...
# 18  POLYGON ((-106.64548 31.89867, -106.64084 31.9...
# 19  POLYGON ((-98.04989 30.62415, -98.03034 30.660...
# 20  POLYGON ((-100.15184 32.09064, -100.15170 32.1...
# 21  MULTIPOLYGON (((-97.24647 27.68248, -97.23737 ...
# 22  POLYGON ((-97.54798 32.79840, -97.54770 32.821...
# 23  POLYGON ((-98.06808 32.52341, -98.06684 32.558...
# 24  POLYGON ((-97.55053 32.56258, -97.55053 32.562...
# 25  POLYGON ((-98.92061 29.98912, -98.92049 30.084...
# 26  POLYGON ((-104.10103 31.12474, -104.10033 31.1...
# 27  MULTIPOLYGON (((-97.12705 27.84106, -97.12289 ...
# 28  MULTIPOLYGON (((-94.71830 29.72885, -94.71721 ...
# 29  POLYGON ((-95.57473 29.86719, -95.56919 29.867...
# 30  POLYGON ((-95.85772 33.46272, -95.85712 33.495...

# %%
def azSmdDistricting(countyNum):
    num = int(countyNum)
    if(num in {15,5}):
        return 1
    if(num in {25}):
        return 2
    if(num in {1, 17}):
        return 3
    if(num in {11,9}):
        return 4
    if(num in {19,23}):
        return 5
    if(num in {21}):
        return 6
    if(num in {13,7}):
        return 7
    if(num in {27,12}):
        return 8
    if(num in {3}):
        return 9
    
    
    return 9

# %%
def azMmdDistricting(countyNum):
    num = int(countyNum)
    if(num in {15,25,5,17,1}):
        return 1
    if(num in {12,27,13}):
        return 2
    if(num in {7,21,9,11,3,19,23}):
        return 3
    
    
    return 3

# %%
def utSmdDistricting(countyNum):
    num = int(countyNum)
    if(num in {37,25,53,21,17,}):
        return 1
    if(num in {55,31,1,41,27,39,23}):
        return 2
    if(num in {15,19,7,47,13,9}):
        return 3
    if(num in {3,5,33,57,11,29,43}):
        return 4
    
    
    return 4

# %%
def utMmdDistricting(countyNum):
    return 1

# %%
def txSmdDistricting(countyNum):
    num = int(countyNum)
    return num

# %%
def txMmdDistricting(countyNum):
    num = int(countyNum)
    if(num in {32,28}):
        return 1
    if(num in {29,19}):
        return 2
    if(num in {24,30}):
        return 3
    if(num in {21,20,27}):
        return 4
    if(num in {17,13,15,11,6}):
        return 5
    if(num in {24,22}):
        return 6
    if(num in {10,12,16,8,2,12}):
        return 7
    if(num in {1}):
        return 8
    return 8

# %%
azSMD['district'] = az['countyNum'].apply(azSmdDistricting)
azMMD['district'] = az['countyNum'].apply(azMmdDistricting)
utSMD['district'] = ut['countyNum'].apply(utSmdDistricting)
utMMD['district'] = ut['countyNum'].apply(utMmdDistricting)

txSMD['district'] = txSMD['NAME']
txMMD['district'] = txMMD['NAME'].apply(txMmdDistricting)
txMMD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 7
#       4 utMMD['district'] = ut['countyNum'].apply(utMmdDistricting)
#       6 txSMD['district'] = txSMD['NAME']
# ----> 7 txMMD['district'] = txMMD['NAME'].apply(txMmdDistricting)
#       8 txMMD
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# -> 1088 return self.apply_standard()
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\apply.py:1143, in SeriesApply.apply_standard(self)
#    1137         values = obj.astype(object)._values
#    1138         # error: Argument 2 to "map_infer" has incompatible type
#    1139         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1140         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1141         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142         # "Callable[[Any], Any]"
# -> 1143         mapped = lib.map_infer(
#    1144             values,
#    1145             f,  # type: ignore[arg-type]
#    1146             convert=self.convert_dtype,
#    1147         )
#    1149 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1150     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1151     #  See also GH#25959 regarding EA support
#    1152     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\envs\geo_env\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Cell In [13], line 2, in txMmdDistricting(countyNum)
#       1 def txMmdDistricting(countyNum):
# ----> 2     if(num in {32,28}):
#       3         return 1
#       4     if(num in {29,19}):
#
# NameError: name 'num' is not defined

# %%
azSMD = azSMD.dissolve(by = 'district')
azMMD = azMMD.dissolve(by = 'district')
utSMD = utSMD.dissolve(by = 'district')
utMMD = utMMD.dissolve(by = 'district')
txMMD = txMMD.dissolve(by = 'district')
display(txMMD)

# %%
##az.to_file("gui_review/az.json", driver='GeoJSON')
##tx.to_file("gui_review/tx.json", driver='GeoJSON')
##ut.to_file("gui_review/ut.json", driver='GeoJSON')

# %%
azSMD.to_file("gui_review/azs.json", driver='GeoJSON')
txSMD.to_file("gui_review/txs.json", driver='GeoJSON')
utSMD.to_file("gui_review/uts.json", driver='GeoJSON')

azMMD.to_file("gui_review/azm.json", driver='GeoJSON')
txMMD.to_file("gui_review/txm.json", driver='GeoJSON')
utMMD.to_file("gui_review/utm.json", driver='GeoJSON')
